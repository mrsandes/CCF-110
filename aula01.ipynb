# %%
# 1000

print("Hello World!")

# %%
# 1001

a = int(input())
b = int(input())

print("X = ", a + b)

# %%
# 1002

r = float(input())
pi = 3.14159
a = pi * r**2

print(f"A={a:.4f}")

# %%
# 1003

a = int(input())
b = int(input())

print("SOMA =", a + b)

# %%
# 1004

a = int(input())
b = int(input())

print("PROD =", a * b)
