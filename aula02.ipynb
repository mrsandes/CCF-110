# %%
# 1005

A = float(input(""))
B = float(input(""))

print(f"MEDIA = {(A * 3.5 + B * 7.5) / 11:.5f}")

# %%
# 1006

A = float(input(""))
B = float(input(""))
C = float(input(""))

print(f"MEDIA = {(A * 2 + B * 3 + C * 5) / 10:.1f}")

# %%
# 1007

A = int(input(""))
B = int(input(""))
C = int(input(""))
D = int(input(""))

print(f"DIFERENCA = {A * B - C * D}")

# %%
# 1008

number = int(input(""))
hours = int(input(""))
value = float(input(""))

print(f"NUMBER = {number}")
print(f"SALARY = U$ {hours * value:.2f}")

# %%
# 1009

name = input("")
salary = float(input(""))
products = float(input(""))

print(f"TOTAL = R$ {salary + products * 0.15:.2f}")

# %%
# 1010

produto1 = input("").split()
produto2 = input("").split()

print(f"VALOR A PAGAR: R$ {int(produto1[1]) * float(produto1[2]) + int(produto2[1]) * float(produto2[2]):.2f}")

# %%
# 1011

R = float(input(""))

print(f"VOLUME = {(4/3) * 3.14159 * R**3:.3f}")

# %%
# 1012

values = list(map(float, input("").split()))

print(f"TRIANGULO: {(values[0] * values[2]) / 2:.3f}")
print(f"CIRCULO: {3.14159 * values[2]**2:.3f}")
print(f"TRAPEZIO: {((values[0] + values[1]) * values[2]) / 2:.3f}")
print(f"QUADRADO: {values[1]**2:.3f}")
print(f"RETANGULO: {values[0] * values[1]:.3f}")

# %%
# 1013

a, b, c = list(map(int, input("").split()))
maiorAB = (a + b + abs(a - b)) / 2
maior = (maiorAB + c + abs(maiorAB - c)) / 2

print(f"{int(maior)} eh o maior")

# %%
# 1014

distance = int(input(""))
fuel = float(input(""))

print(f"{distance / fuel:.3f} km/l")

# %%
# 1015

import math

x1, y1 = list(map(float, input("").split()))
x2, y2 = list(map(float, input("").split()))

print(f"{math.sqrt((x2 - x1)**2 + (y2 - y1)**2):.4f}")

# %%
# 1016

distance = int(input(""))

print(f"{int(distance / 30 * 60)} minutos")

# %%
# 1017

tempo = int(input(""))
velocidade = int(input(""))

print(f"{tempo * velocidade / 12:.3f}")
